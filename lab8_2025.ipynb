# %% [markdown]
# [<img src="https://raw.githubusercontent.com/mbakker7/exploratory_computing_with_python/master/tudelft_logo.png" width="200" align='right'>](https://www.tudelft.nl/citg/over-faculteit/afdelingen/geoscience-remote-sensing/staff/scientific-staff/dr-stef-lhermitte)
#
#
# # Lab 8 - Advanced Data Visualization
# *Date: Sep. 24th, 2025*
#
# *Lecturer: Yanan Xin (yanan.xin at tudelft.nl);*
# *Teaching Assistant: Sherman Lee*
#
# *This assignment is prepared for the TIL6022 Python Programming course offered in 2025/2026 Q1.*

# %% [markdown]
# Let's first import all the necessary Python packages for this lab. Make sure that you install these packages first in your virtual environment created for this class.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.io as pio
import numpy as np
import streamlit as st
import nbformat

# %% [markdown]
# To display interactive plots directly inside the notebook, let's set the default renderer for Plotly plots using the following commands.

# %%
pio.renderers.default = "plotly_mimetype+notebook"

# %% [markdown]
# # 3D Plot with Matplotlib

# %% [markdown]
# ## Question 1:
#
# For this excercise, you first need to generate the 3D data (x, y, z). The x and y are given, see below. z follows a relationships of $z = \sin\!\left(\sqrt{x^2 + y^2}\right)$. Please complete the function to generate z based on x and y.
#
# ```python
# x = np.linspace(-10, 10, 20)
# y = np.linspace(-10, 10, 20)
# ```

# %%
def generate_z(x, y):
    # Complete the function to generate z based on x and y
    z = 
    return z # z should be a 2D array with shape (len(x), len(y))

# %% [markdown]
# Now we will create a matplotlib figure with the (x, y, z) data to generate two subplots that are put side by side: (1) 3D surface plot on the left, use the colormap 'viridis', and (2) 3D wireframe plot on the right, use the color 'blue'.

# %%
def create_3d_plots():
    # Generate x and y data
    x = np.linspace(-10, 10, 20)
    y = np.linspace(-10, 10, 20)
    X, Y = np.meshgrid(x, y)
    Z = generate_z(X, Y)

    # Create a matplotlib figure with two subplots
    # complete your code here
    
    plt.show()

    axes = fig.get_axes()

    # do not modify the code below, for testing purpose only
    return {
        "num_plots": len(axes),
        "ax1_color_map": ax1.collections[0].cmap.name,
        "ax2_color": ax2.collections[0].get_color(),
    }


create_3d_plots();

# %%
test_q1 = create_3d_plots();

# %% [markdown]
# # Geospatial Visualization

# %% [markdown]
# ## Question 2:
#
# In this question, we are going to use plotly express to create a world map that shows the life expentancy of each country for the year 2007. The data we are going to use is from plotly express gapminder.
#
# For the plot, please satisfy the following requirements:
# - color: use the lifeExp column to color the country
# - hover_name: country
# - color scale: px.colors.sequential.Blues_r
# - title: '2007 Life Expectancy'
#
# *Hint:* Use locations='iso_alpha'

# %%
# load the gapminder dataset
df = px.data.gapminder()
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
# Filter the data for the year 2007

# create the plotly express map here
q2_fig = 

q2_fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="66efcab3-d3e5-4118-91dd-4462abea7970" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("66efcab3-d3e5-4118-91dd-4462abea7970")) {                    Plotly.newPlot(                        "66efcab3-d3e5-4118-91dd-4462abea7970",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eiso_alpha=%{location}\u003cbr\u003elifeExp=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Albani
# ...

# %%
# do not modify the code below, for testing purpose only
test_q2 = {
    "color_scale": q2_fig.data[0].colorscale,
    "title": q2_fig.layout.title.text
}
